# %%
from Bio import SeqIO
import pandas as pd
import numpy as np
from pandas import ExcelWriter
from pandas import ExcelFile

def split(word): 
    return [char for char in word]  


def main():
    
    AA=[] 
    CC=[] 
    DD=[] 
    EE=[] 
    FF=[] 
    GG=[] 
    HH=[] 
    II=[] 
    KK=[] 
    LL=[] 
    MM=[] 
    NN=[] 
    PP=[] 
    QQ=[] 
    RR=[] 
    SS=[] 
    TT=[] 
    VV=[] 
    WW=[] 
    YY=[] 
    XX=[]
    New_K=[]
    Amino_lst=[]
    K_index=[]
    K_index_N=[]
    for_value=[]
    all_value=[]
    truncated=[]
    full_truncated=[]
    Seq=[]
    lst=[]
    gluta=[]
    yes=[]
    img_list=[]
    
    f= open("Dataset_creation.txt","w+")
    df_train = pd.read_excel('Dataset.xls', sheet_name='Training data')
    df_test = pd.read_excel('Dataset.xls', sheet_name='Testing data')
    names = list(df_test['Uniprot Accession'])
    peptide=list(df_test['Peptide'])
    target=list(df_test['Glutarylated?'])
    
    names_len=len(names)
    pep_len=len(peptide)
    target_len=len(target)
#     value = list(df['Position'])
    for i in peptide:
        SP_truncated=split(i)
        truncated.append(SP_truncated)
#     print(truncated)
    
    print(target_len)
    
    truncated_len=len(truncated)
    print("\n")
#     print(lst)
    for i in target:
        if(i=='Yes'):
            gluta='1'
        else:
            gluta='0'
        lst.append(gluta)
#     print(lst)

    Uniprot=[]
    Site=[]
    Peptide=[]
    Glutarylation=[]
# DataFrame/dataset Create                    


    for j in range(0,names_len):
        L_lenth=len(lst[j])
        L_value=lst[j]
        for k in L_value:
            Glutarylation.append(k)
#     print(Acetylation)
    
    for i in range(0,truncated_len):

        df_Encoding = pd.DataFrame(
            {'Peptide': truncated[i]
             }
        )
        df_Encoding['A'] = df_Encoding['Peptide'].apply(lambda x: 1 if x == 'A' else 0)
        df_Encoding['C'] = df_Encoding['Peptide'].apply(lambda x: 1 if x == 'C' else 0)
        df_Encoding['D'] = df_Encoding['Peptide'].apply(lambda x: 1 if x == 'D' else 0)
        df_Encoding['E'] = df_Encoding['Peptide'].apply(lambda x: 1 if x == 'E' else 0)
        df_Encoding['F'] = df_Encoding['Peptide'].apply(lambda x: 1 if x == 'F' else 0)
        df_Encoding['G'] = df_Encoding['Peptide'].apply(lambda x: 1 if x == 'G' else 0)
        df_Encoding['H'] = df_Encoding['Peptide'].apply(lambda x: 1 if x == 'H' else 0)
        df_Encoding['I'] = df_Encoding['Peptide'].apply(lambda x: 1 if x == 'I' else 0)
        df_Encoding['K'] = df_Encoding['Peptide'].apply(lambda x: 1 if x == 'K' else 0)
        df_Encoding['L'] = df_Encoding['Peptide'].apply(lambda x: 1 if x == 'L' else 0)
        df_Encoding['M'] = df_Encoding['Peptide'].apply(lambda x: 1 if x == 'M' else 0)
        df_Encoding['N'] = df_Encoding['Peptide'].apply(lambda x: 1 if x == 'N' else 0)
        df_Encoding['P'] = df_Encoding['Peptide'].apply(lambda x: 1 if x == 'P' else 0)
        df_Encoding['Q'] = df_Encoding['Peptide'].apply(lambda x: 1 if x == 'Q' else 0)
        df_Encoding['R'] = df_Encoding['Peptide'].apply(lambda x: 1 if x == 'R' else 0)
        df_Encoding['S'] = df_Encoding['Peptide'].apply(lambda x: 1 if x == 'S' else 0)
        df_Encoding['T'] = df_Encoding['Peptide'].apply(lambda x: 1 if x == 'T' else 0)
        df_Encoding['V'] = df_Encoding['Peptide'].apply(lambda x: 1 if x == 'V' else 0)
        df_Encoding['W'] = df_Encoding['Peptide'].apply(lambda x: 1 if x == 'W' else 0)
        df_Encoding['Y'] = df_Encoding['Peptide'].apply(lambda x: 1 if x == 'Y' else 0)
        df_Encoding['X'] = df_Encoding['Peptide'].apply(lambda x: 1 if x == 'X' else 0)
        
        dff=df_Encoding.drop(['Peptide'],axis=1)
        
        NP=dff.values.tolist()
#         NP=dff.to_numpy()
        img_list.append(NP)
        
#             df.to_csv('/Users/urmis/Documents/Thesis/Binary_Encoding.csv',index=False)
            

#     print(img_list[0].shape)

    raw_data ={
            'Image_Array': img_list,
            'Glutarylation':Glutarylation
            }
    Frame=pd.DataFrame(raw_data,columns=['Image_Array','Glutarylation'])
    Frame.to_csv('/Users/urmis/Downloads/DeepGlut-master/DeepGlut-master/test_Binary_Encoding.csv',index=False)
    print("ok")
    
            

main()
# Out:
# 484
#
#
# ok
